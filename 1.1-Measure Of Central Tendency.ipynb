# %% [markdown]
# ## Measure Of Central Tendency

# %% [markdown]
# Center of Tendency actually looks at clusters around the centre of your data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Mean (Average)
age=[12,13,14,21,24]

# %%
(12+13+14+21+24)/5
# Out:
# 16.8

# %%
import numpy as np
np.mean(age)
# Out:
# 16.8

# %%
weights=[45,34,55,76,45,35,89,98,75]

# %%
np.mean(weights)
# Out:
# 61.333333333333336

# %%
weights=[45,34,55,76,45,35,89,98,75,1000]

# %%
np.mean(weights)
# Out:
# 61.333333333333336

# %%
## Median

# %%
np.median(weights)
# Out:
# 55.0

# %%
## mode

# %%
from scipy import stats

# %%
stats.mode(weights)
# Out:
# ModeResult(mode=array([45]), count=array([2]))

# %%
### The End
